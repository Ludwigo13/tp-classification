# %% [markdown]
# # Lib Import

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %% [markdown]
# # EDA

# %% [markdown]
# ## Data import

# %%
df = pd.read_csv("pet_adoption_data.csv")
df.head()
# Out:
#    PetID PetType             Breed  AgeMonths   Color    Size   WeightKg  \
# 0    500    Bird          Parakeet        131  Orange   Large   5.039768
# 1    501  Rabbit            Rabbit         73   White   Large  16.086727
# 2    502     Dog  Golden Retriever        136  Orange  Medium   2.076286
# 3    503    Bird          Parakeet         97   White   Small   3.339423
# 4    504  Rabbit            Rabbit        123    Gray   Large  20.498100
#
#    Vaccinated  HealthCondition  TimeInShelterDays  AdoptionFee  PreviousOwner  \
# 0           1                0                 27          140              0
# 1           0                0                  8          235              0
# 2           0                0                 85          385              0
# 3           0                0                 61          217              1
# 4           0                0                 28           14              1
#
#    AdoptionLikelihood
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2007 entries, 0 to 2006
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PetID               2007 non-null   int64
#  1   PetType             2007 non-null   object
#  2   Breed               2007 non-null   object
#  3   AgeMonths           2007 non-null   int64
#  4   Color               2007 non-null   object
#  5   Size                2007 non-null   object
#  6   WeightKg            2007 non-null   float64
#  7   Vaccinated          2007 non-null   int64
#  8   HealthCondition     2007 non-null   int64
#  9   TimeInShelterDays   2007 non-null   int64
#  10  AdoptionFee         2007 non-null   int64
#  11  PreviousOwner       2007 non-null   int64
#  12  AdoptionLikelihood  2007 non-null   int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 204.0+ KB

# %%
df.describe()
# Out:
#              PetID    AgeMonths     WeightKg   Vaccinated  HealthCondition  \
# count  2007.000000  2007.000000  2007.000000  2007.000000      2007.000000
# mean   1503.000000    92.279522    15.705776     0.701046         0.196313
# std     579.515315    52.148363     8.327749     0.457914         0.397307
# min     500.000000     1.000000     1.018198     0.000000         0.000000
# 25%    1001.500000    48.000000     8.730396     0.000000         0.000000
# 50%    1503.000000    94.000000    15.925416     1.000000         0.000000
# 75%    2004.500000   138.000000    22.737180     1.000000         0.000000
# max    2506.000000   179.000000    29.995628     1.000000         1.000000
#
#        TimeInShelterDays  AdoptionFee  PreviousOwner  AdoptionLikelihood
# count        2007.000000  2007.000000    2007.000000         2007.000000
# mean           43.974091   249.142003       0.301943            0.328351
# std            25.740253   142.887040       0.459215            0.469730
# min             1.000000     0.000000       0.000000            0.000000
# 25%            21.000000   127.000000       0.000000            0.000000
# 50%            45.000000   242.000000       0.000000            0.000000
# 75%            66.000000   375.000000       1.000000            1.000000
# max            89.000000   499.000000       1.000000            1.000000

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ## Standardizing

# %%
x = df.drop(["PetID", "AdoptionLikelihood"], axis=1)
x
# Out:
#      PetType             Breed  AgeMonths   Color    Size   WeightKg  \
# 0       Bird          Parakeet        131  Orange   Large   5.039768
# 1     Rabbit            Rabbit         73   White   Large  16.086727
# 2        Dog  Golden Retriever        136  Orange  Medium   2.076286
# 3       Bird          Parakeet         97   White   Small   3.339423
# 4     Rabbit            Rabbit        123    Gray   Large  20.498100
# ...      ...               ...        ...     ...     ...        ...
# 2002     Dog            Poodle         72  Orange   Small  27.039045
# 2003  Rabbit            Rabbit        124   Brown   Small   4.726954
# 2004  Rabbit            Rabbit        113  Orange   Small   1.758592
# 2005     Dog          Labrador         12    Gray   Large  20.961592
# 2006  Rabbit            Rabbit        126   White  Medium  18.519788
#
#       Vaccinated  HealthCondition  TimeInShelterDays  AdoptionFee  \
# 0              1                0                 27          140
# 1              0                0                  8          235
# 2              0                0                 85          385
# 3              0                0                 61          217
# 4              0                0                 28           14
# ...          ...              ...                ...          ...
# 2002           1                0                 66           26
# 2003           1                1                 59          150
# 2004           1                0                 68          302
# 2005           1                0                 59          478
# 2006           1                0                 10          267
#
#       PreviousOwner
# 0                 0
# 1                 0
# 2                 0
# 3                 1
# 4                 1
# ...             ...
# 2002              1
# 2003              0
# 2004              0
# 2005              0
# 2006              1
#
# [2007 rows x 11 columns]

# %%
target = df['AdoptionLikelihood']
target
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2002    1
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# Name: AdoptionLikelihood, Length: 2007, dtype: int64

# %%
numerical_variables = ['AgeMonths','WeightKg','TimeInShelterDays','AdoptionFee']
scaler = StandardScaler()
x[numerical_variables] = scaler.fit_transform(x[numerical_variables])
x
# Out:
#      PetType             Breed  AgeMonths   Color    Size  WeightKg  \
# 0       Bird          Parakeet   0.742691  Orange   Large -1.281098
# 1     Rabbit            Rabbit  -0.369797   White   Large  0.045756
# 2        Dog  Golden Retriever   0.838595  Orange  Medium -1.637043
# 3       Bird          Parakeet   0.090543   White   Small -1.485328
# 4     Rabbit            Rabbit   0.589244    Gray   Large  0.575608
# ...      ...               ...        ...     ...     ...       ...
# 2002     Dog            Poodle  -0.388978  Orange   Small  1.361243
# 2003  Rabbit            Rabbit   0.608425   Brown   Small -1.318671
# 2004  Rabbit            Rabbit   0.397436  Orange   Small -1.675202
# 2005     Dog          Labrador  -1.539828    Gray   Large  0.631278
# 2006  Rabbit            Rabbit   0.646787   White  Medium  0.337992
#
#       Vaccinated  HealthCondition  TimeInShelterDays  AdoptionFee  \
# 0              1                0          -0.659602    -0.764025
# 1              0                0          -1.397929    -0.098998
# 2              0                0           1.594240     0.951044
# 3              0                0           0.661616    -0.225003
# 4              0                0          -0.620743    -1.646060
# ...          ...              ...                ...          ...
# 2002           1                0           0.855912    -1.562056
# 2003           1                1           0.583897    -0.694022
# 2004           1                0           0.933631     0.370021
# 2005           1                0           0.583897     1.602070
# 2006           1                0          -1.320211     0.125011
#
#       PreviousOwner
# 0                 0
# 1                 0
# 2                 0
# 3                 1
# 4                 1
# ...             ...
# 2002              1
# 2003              0
# 2004              0
# 2005              0
# 2006              1
#
# [2007 rows x 11 columns]

# %% [markdown]
# ## One Hot Encoding

# %%
cat_variables = ['PetType', 'Breed', 'Color']
x = pd.get_dummies(x, columns=cat_variables, prefix=cat_variables)
x
# Out:
#       AgeMonths    Size  WeightKg  Vaccinated  HealthCondition  \
# 0      0.742691   Large -1.281098           1                0
# 1     -0.369797   Large  0.045756           0                0
# 2      0.838595  Medium -1.637043           0                0
# 3      0.090543   Small -1.485328           0                0
# 4      0.589244   Large  0.575608           0                0
# ...         ...     ...       ...         ...              ...
# 2002  -0.388978   Small  1.361243           1                0
# 2003   0.608425   Small -1.318671           1                1
# 2004   0.397436   Small -1.675202           1                0
# 2005  -1.539828   Large  0.631278           1                0
# 2006   0.646787  Medium  0.337992           1                0
#
#       TimeInShelterDays  AdoptionFee  PreviousOwner  PetType_Bird  \
# 0             -0.659602    -0.764025              0          True
# 1             -1.397929    -0.098998              0         False
# 2              1.594240     0.951044              0         False
# 3              0.661616    -0.225003              1          True
# 4             -0.620743    -1.646060              1         False
# ...                 ...          ...            ...           ...
# 2002           0.855912    -1.562056              1         False
# 2003           0.583897    -0.694022              0         False
# 2004           0.933631     0.370021              0         False
# 2005           0.583897     1.602070              0         False
# 2006          -1.320211     0.125011              1         False
#
#       PetType_Cat  ...  Breed_Parakeet  Breed_Persian  Breed_Poodle  \
# 0           False  ...            True          False         False
# 1           False  ...           False          False         False
# 2           False  ...           False          False         False
# 3           False  ...            True          False         False
# 4           False  ...           False          False         False
# ...           ...  ...             ...            ...           ...
# 2002        False  ...           False          False          True
# 2003        False  ...           False          False         False
# 2004        False  ...           False          False         False
# 2005        False  ...           False          False         False
# 2006        False  ...           False          False         False
#
#       Breed_Rabbit  Breed_Siamese  Color_Black  Color_Brown  Color_Gray  \
# 0            False          False        False        False       False
# 1             True          False        False        False       False
# 2            False          False        False        False       False
# 3            False          False        False        False       False
# 4             True          False        False        False        True
# ...            ...            ...          ...          ...         ...
# 2002         False          False        False        False       False
# 2003          True          False        False         True       False
# 2004          True          False        False        False       False
# 2005         False          False        False        False        True
# 2006          True          False        False        False       False
#
#       Color_Orange  Color_White
# 0             True        False
# 1            False         True
# 2             True        False
# 3            False         True
# 4            False        False
# ...            ...          ...
# 2002          True        False
# 2003         False        False
# 2004          True        False
# 2005         False        False
# 2006         False         True
#
# [2007 rows x 24 columns]

# %% [markdown]
# ## Ordinal Encoding

# %%
encoder = OrdinalEncoder(categories=[['Small', 'Medium', 'Large']])
x['Size'] = encoder.fit_transform(x[['Size']])
x
# Out:
#       AgeMonths  Size  WeightKg  Vaccinated  HealthCondition  \
# 0      0.742691   2.0 -1.281098           1                0
# 1     -0.369797   2.0  0.045756           0                0
# 2      0.838595   1.0 -1.637043           0                0
# 3      0.090543   0.0 -1.485328           0                0
# 4      0.589244   2.0  0.575608           0                0
# ...         ...   ...       ...         ...              ...
# 2002  -0.388978   0.0  1.361243           1                0
# 2003   0.608425   0.0 -1.318671           1                1
# 2004   0.397436   0.0 -1.675202           1                0
# 2005  -1.539828   2.0  0.631278           1                0
# 2006   0.646787   1.0  0.337992           1                0
#
#       TimeInShelterDays  AdoptionFee  PreviousOwner  PetType_Bird  \
# 0             -0.659602    -0.764025              0          True
# 1             -1.397929    -0.098998              0         False
# 2              1.594240     0.951044              0         False
# 3              0.661616    -0.225003              1          True
# 4             -0.620743    -1.646060              1         False
# ...                 ...          ...            ...           ...
# 2002           0.855912    -1.562056              1         False
# 2003           0.583897    -0.694022              0         False
# 2004           0.933631     0.370021              0         False
# 2005           0.583897     1.602070              0         False
# 2006          -1.320211     0.125011              1         False
#
#       PetType_Cat  ...  Breed_Parakeet  Breed_Persian  Breed_Poodle  \
# 0           False  ...            True          False         False
# 1           False  ...           False          False         False
# 2           False  ...           False          False         False
# 3           False  ...            True          False         False
# 4           False  ...           False          False         False
# ...           ...  ...             ...            ...           ...
# 2002        False  ...           False          False          True
# 2003        False  ...           False          False         False
# 2004        False  ...           False          False         False
# 2005        False  ...           False          False         False
# 2006        False  ...           False          False         False
#
#       Breed_Rabbit  Breed_Siamese  Color_Black  Color_Brown  Color_Gray  \
# 0            False          False        False        False       False
# 1             True          False        False        False       False
# 2            False          False        False        False       False
# 3            False          False        False        False       False
# 4             True          False        False        False        True
# ...            ...            ...          ...          ...         ...
# 2002         False          False        False        False       False
# 2003          True          False        False         True       False
# 2004          True          False        False        False       False
# 2005         False          False        False        False        True
# 2006          True          False        False        False       False
#
#       Color_Orange  Color_White
# 0             True        False
# 1            False         True
# 2             True        False
# 3            False         True
# 4            False        False
# ...            ...          ...
# 2002          True        False
# 2003         False        False
# 2004          True        False
# 2005         False        False
# 2006         False         True
#
# [2007 rows x 24 columns]

# %% [markdown]
# ## Set Bool variable type

# %%
bool_variables = ['Vaccinated', 'HealthCondition', 'PreviousOwner']
x[bool_variables] = x[bool_variables].astype(bool)
x
# Out:
#       AgeMonths  Size  WeightKg  Vaccinated  HealthCondition  \
# 0      0.742691   2.0 -1.281098        True            False
# 1     -0.369797   2.0  0.045756       False            False
# 2      0.838595   1.0 -1.637043       False            False
# 3      0.090543   0.0 -1.485328       False            False
# 4      0.589244   2.0  0.575608       False            False
# ...         ...   ...       ...         ...              ...
# 2002  -0.388978   0.0  1.361243        True            False
# 2003   0.608425   0.0 -1.318671        True             True
# 2004   0.397436   0.0 -1.675202        True            False
# 2005  -1.539828   2.0  0.631278        True            False
# 2006   0.646787   1.0  0.337992        True            False
#
#       TimeInShelterDays  AdoptionFee  PreviousOwner  PetType_Bird  \
# 0             -0.659602    -0.764025          False          True
# 1             -1.397929    -0.098998          False         False
# 2              1.594240     0.951044          False         False
# 3              0.661616    -0.225003           True          True
# 4             -0.620743    -1.646060           True         False
# ...                 ...          ...            ...           ...
# 2002           0.855912    -1.562056           True         False
# 2003           0.583897    -0.694022          False         False
# 2004           0.933631     0.370021          False         False
# 2005           0.583897     1.602070          False         False
# 2006          -1.320211     0.125011           True         False
#
#       PetType_Cat  ...  Breed_Parakeet  Breed_Persian  Breed_Poodle  \
# 0           False  ...            True          False         False
# 1           False  ...           False          False         False
# 2           False  ...           False          False         False
# 3           False  ...            True          False         False
# 4           False  ...           False          False         False
# ...           ...  ...             ...            ...           ...
# 2002        False  ...           False          False          True
# 2003        False  ...           False          False         False
# 2004        False  ...           False          False         False
# 2005        False  ...           False          False         False
# 2006        False  ...           False          False         False
#
#       Breed_Rabbit  Breed_Siamese  Color_Black  Color_Brown  Color_Gray  \
# 0            False          False        False        False       False
# 1             True          False        False        False       False
# 2            False          False        False        False       False
# 3            False          False        False        False       False
# 4             True          False        False        False        True
# ...            ...            ...          ...          ...         ...
# 2002         False          False        False        False       False
# 2003          True          False        False         True       False
# 2004          True          False        False        False       False
# 2005         False          False        False        False        True
# 2006          True          False        False        False       False
#
#       Color_Orange  Color_White
# 0             True        False
# 1            False         True
# 2             True        False
# 3            False         True
# 4            False        False
# ...            ...          ...
# 2002          True        False
# 2003         False        False
# 2004          True        False
# 2005         False        False
# 2006         False         True
#
# [2007 rows x 24 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, target, test_size=0.2, random_state=13)

# %%
len(x_train)
# Out:
# 1605

# %%
len(x_test)
# Out:
# 402

# %% [markdown]
# # Model Creation

# %% [markdown]
# ## kNN

# %% [markdown]
# ### Finding best k

# %%
k_range = range(1, 61)
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)
    y_pred = knn.predict(x_test)
    scores.append(accuracy_score(y_test, y_pred))

# %%
plt.plot(k_range, scores)
plt.xlabel('Value of K for kNN')
plt.ylabel('Testing Accuracy')
# Out:
# Text(0, 0.5, 'Testing Accuracy')

# %% [markdown]
# ### Model with best k

# %%
best_k = 35
knn = KNeighborsClassifier(n_neighbors=best_k)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy with k = {best_k} is {accuracy}")
# Out:
# Accuracy with k = 35 is 0.7810945273631841

# %% [markdown]
# ## Logistic Regression

# %%
logr = LogisticRegression(solver='lbfgs', max_iter=1000)
logr.fit(x_train, y_train)
y_pred = logr.predict(x_train)
accuracy = logr.score(x_train, y_train)
print(f"Accuracy is {accuracy}")
# Out:
# Accuracy is 0.7613707165109034

# %% [markdown]
# ## RandomForestClassifier

# %% [markdown]
# ### Finding best n_estimators

# %%
n_range = range(135, 145)
scores = []
for n in n_range:
    classifier = RandomForestClassifier(n_estimators=n, random_state=13)
    classifier.fit(x_train, y_train)
    y_pred = classifier.predict(x_test)
    scores.append(accuracy_score(y_test, y_pred))

# %%
plt.plot(n_range, scores)
plt.xlabel('Value of n_estimators for RandomForestClassifier')
plt.ylabel('Testing Accuracy')
# Out:
# Text(0, 0.5, 'Testing Accuracy')

# %% [markdown]
# ### Model with best n_estimators

# %%
classifier = RandomForestClassifier(n_estimators=140, random_state=13)
classifier.fit(x_train, y_train)
y_pred = classifier.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy is {accuracy}")
# Out:
# Accuracy is 0.9427860696517413
